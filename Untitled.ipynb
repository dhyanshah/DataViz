# %%
import altair as alt
# alt.renderers.enable('notebook')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/Dhyan/Data_Visualization/case_study_3b.xlsx", header = [0], skipinitialspace=True)
df.head()
# Out:
#    Adv_Age  2015Q1  2015Q2  2015Q3  2015Q4  2016Q1  2016Q2  2016Q3  2016Q4  \
# 0       16    0.13    0.17    0.14    0.17    0.16    0.18    0.17    0.19
# 1       15     NaN    0.21    0.18    0.18    0.18    0.19    0.21    0.22
# 2       14     NaN     NaN    0.20    0.20    0.20    0.19    0.20    0.22
# 3       13     NaN     NaN     NaN    0.20    0.27    0.26    0.23    0.23
# 4       12     NaN     NaN     NaN     NaN    0.21    0.26    0.27    0.26
#
#    2017Q1  2017Q2  2017Q3  2017Q4  2018Q1  2018Q2  2018Q3  2018Q4  2019Q1
# 0    0.21    0.22    0.24    0.23    0.24    0.25    0.26    0.25    0.28
# 1    0.23    0.23    0.25    0.26    0.23    0.26    0.31    0.30    0.33
# 2    0.24    0.25    0.22    0.22    0.23    0.25    0.29    0.31    0.32
# 3    0.24    0.23    0.23    0.24    0.24    0.27    0.27    0.33    0.34
# 4    0.25    0.24    0.25    0.23    0.26    0.28    0.29    0.30    0.34

# %%
#df_t = df.T
#df_t.head()

# %%
#sns.pairplot(df)

# %%
del df['Adv_Age']

# %%
fig, ax = plt.subplots(figsize=(10,15)) 
sns.heatmap(df.corr(), cmap='coolwarm',annot = True, linewidth = 0.5)

# %%
alt.Chart(source).mark_line().encode(
    alt.X('year:O'),
    alt.Y('perc:Q', axis=alt.Axis(format='%')),
    color='sex:N'
).transform_filter(
    alt.datum.job == 'Welder'
)
